# %% [markdown]
# *This analysis goes over two very helpful techniques:*
#
# 1. The use of commands such as re.search as part of the RegEx expressions to extract values from strings.
# 2. Fuzzy String Matching.
#
# Data Source: San_francisco_bikeshare, Big_Query, Google Cloud.

# %% [markdown]
# First: importing required environments.

# %%
import pandas as pd
import numpy as np
import re
from fuzzywuzzy import fuzz,process

# %% [markdown]
# Second: reading cvs dataset.

# %%
df = pd.read_csv('SFbikesharetrips.csv', encoding='latin1')

# %% [markdown]
# Third: examining data and variables.

# %%
df.head(5)
# Out:
#                 start_date              start_station_name  start_station_id  \
# 0  2018-03-31 22:13:30 UTC            Post St at Kearny St                19
# 1  2018-03-31 21:18:59 UTC  Valencia St at Cesar Chavez St               141
# 2  2018-03-31 20:24:12 UTC       Fulton St at Bancroft Way               247
# 3  2018-03-31 19:46:11 UTC      S. 4th St at San Carlos St               208
# 4  2018-03-31 17:18:07 UTC        Telegraph Ave at 27th St               179
#
#                   end_date               end_station_name  end_station_id  \
# 0  2018-03-31 22:34:35 UTC         Broderick St at Oak St              71
# 1  2018-03-31 21:24:24 UTC         Valencia St at 22nd St             133
# 2  2018-03-31 21:21:09 UTC              45th St at Manila             210
# 3  2018-03-31 19:51:35 UTC      San Salvador St at 9th St             317
# 4  2018-03-31 19:03:30 UTC  Shattuck Ave at Telegraph Ave             158
#
#    bike_number  start_station_latitude  start_station_longitude  \
# 0         1021               37.788975              -122.403452
# 1         1082               37.747998              -122.420219
# 2         1038               37.867789              -122.265896
# 3         2731               37.332836              -121.883912
# 4         3208               37.816073              -122.267886
#
#    end_station_latitude  end_station_longitude  member_birth_year  \
# 0             37.773063            -122.439078             1993.0
# 1             37.755213            -122.420975             1992.0
# 2             37.833294            -122.256224             1964.0
# 3             37.333955            -121.877349             1992.0
# 4             37.833279            -122.263490                NaN
#
#   member_gender
# 0        Female
# 1          Male
# 2          Male
# 3        Female
# 4           NaN

# %%
df.shape
# Out:
# (1000, 13)

# %%
df.columns
# Out:
# Index([u'start_date', u'start_station_name', u'start_station_id', u'end_date',
#        u'end_station_name', u'end_station_id', u'bike_number',
#        u'start_station_latitude', u'start_station_longitude',
#        u'end_station_latitude', u'end_station_longitude', u'member_birth_year',
#        u'member_gender'],
#       dtype='object')

# %% [markdown]
# Fourth: examining pick-up and drop-off addresses.

# %%
dfstartaddress = df['start_station_name']

# %%
dfstartaddress.head(5)
# Out:
# 0              Post St at Kearny St
# 1    Valencia St at Cesar Chavez St
# 2         Fulton St at Bancroft Way
# 3        S. 4th St at San Carlos St
# 4          Telegraph Ave at 27th St
# Name: start_station_name, dtype: object

# %% [markdown]
# Fifth: identifying main address types.

# %%
pick_up_address = []

for i in dfstartaddress:
    if re.search('St|Way|Ave|5th at Folsom|Broadway at Kearny', i):
        pick_up_address.append('Street Address')
    elif re.search('BART', i):
        pick_up_address.append('Bart Station Address')
    elif re.search('Park|Hall|Center|Square|Playground|Plaza|Public Market', i):
        pick_up_address.append('Public Place Address')
    else:
        pick_up_address.append('')

# %%
df['pick_up_address'] = pick_up_address

# %% [markdown]
# Sixth: making sure all address types have been identified.

# %%
df.isnull().sum()
# Out:
# start_date                  0
# start_station_name          0
# start_station_id            0
# end_date                    0
# end_station_name            0
# end_station_id              0
# bike_number                 0
# start_station_latitude      0
# start_station_longitude     0
# end_station_latitude        0
# end_station_longitude       0
# member_birth_year          63
# member_gender              63
# pick_up_address             0
# dtype: int64

# %%
pick_up_address
# Out:
# ['Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Bart Station Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Bart Station Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Public Place Address',
#  'Public Place Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Bart Station Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Bart Station Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Bart Station Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Bart Station Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address']

# %% [markdown]
# Seventh: examining drop-off address.

# %%
dfendaddress = df['end_station_name']

# %%
dfendaddress.head(5)
# Out:
# 0           Broderick St at Oak St
# 1           Valencia St at 22nd St
# 2                45th St at Manila
# 3        San Salvador St at 9th St
# 4    Shattuck Ave at Telegraph Ave
# Name: end_station_name, dtype: object

# %% [markdown]
# Eighth: identifyng main address types.

# %%
drop_off_address = []

for a in dfendaddress:
    if re.search('St|Way|Ave|5th at Folsom|Broadway at Kearny', a):
        drop_off_address.append('Street Address')
    elif re.search('BART', a):
        drop_off_address.append('Bart Station Address')
    elif re.search('Park|Hall|Center|Square|Playground|Plaza|Public Market', a):
        drop_off_address.append('Public Place Address')
    else:
        drop_off_address.append('')

# %%
df['drop_off_address'] = drop_off_address

# %%
drop_off_address
# Out:
# ['Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Public Place Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Bart Station Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Bart Station Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Bart Station Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Bart Station Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Bart Station Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Public Place Address',
#  'Public Place Address',
#  'Bart Station Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Bart Station Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Bart Station Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Bart Station Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Bart Station Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Bart Station Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Bart Station Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Street Address',
#  'Public Place Address',
#  'Street Address',
#  'Street Address',
#  'Street Address']

# %% [markdown]
# Nineth: making sure all addresses types have been identified.

# %%
df.isnull().sum()
# Out:
# start_date                  0
# start_station_name          0
# start_station_id            0
# end_date                    0
# end_station_name            0
# end_station_id              0
# bike_number                 0
# start_station_latitude      0
# start_station_longitude     0
# end_station_latitude        0
# end_station_longitude       0
# member_birth_year          63
# member_gender              63
# pick_up_address             0
# drop_off_address            0
# dtype: int64

# %% [markdown]
# Tenth: FuzzyWuzzy,
#     setting ratios with pick-up and drop-off addresses, through the
#     application of token set ratios

# %%
def get_ratio(row):
    name = row['pick_up_address']
    namel = row['drop_off_address']
    return fuzz.token_set_ratio(name, namel)

# %% [markdown]
# Restricting the data to the pairs that exceeded a match score of 65.

# %%
df[df.apply(get_ratio, axis=1) > 65]
# Out:
#                   start_date  \
# 0    2018-03-31 22:13:30 UTC
# 1    2018-03-31 21:18:59 UTC
# 2    2018-03-31 20:24:12 UTC
# 3    2018-03-31 19:46:11 UTC
# 4    2018-03-31 17:18:07 UTC
# 5    2018-03-31 18:56:26 UTC
# 6    2018-03-31 17:03:33 UTC
# 7    2018-03-31 16:36:59 UTC
# 8    2018-03-31 16:36:50 UTC
# 9    2018-03-31 16:12:25 UTC
# 10   2018-03-31 15:52:47 UTC
# 11   2018-03-31 15:09:13 UTC
# 12   2018-03-31 15:04:58 UTC
# 13   2018-03-31 15:13:47 UTC
# 14   2018-03-31 14:46:21 UTC
# 15   2018-03-31 14:20:08 UTC
# 16   2018-03-31 14:27:03 UTC
# 17   2018-03-31 14:17:18 UTC
# 18   2018-03-31 14:22:29 UTC
# 19   2018-03-31 13:47:01 UTC
# 20   2018-03-31 14:06:45 UTC
# 21   2018-03-31 13:38:53 UTC
# 22   2018-03-31 13:35:17 UTC
# 23   2018-03-31 13:07:20 UTC
# 24   2018-03-31 12:43:30 UTC
# 25   2018-03-31 12:23:11 UTC
# 26   2018-03-31 11:09:37 UTC
# 27   2018-03-31 10:54:43 UTC
# 980             37.852477            -122.270213             1979.0
# 981             37.766210            -122.426614             1970.0
# 982             37.752428            -122.420628             1972.0
# 983             37.791300            -122.399051             1987.0
# 984             37.765052            -122.421866             1976.0
# 985             37.808848            -122.249680             1957.0
# 986             37.339146            -121.884105             1993.0
# 987             37.808894            -122.256460             1986.0
# 988             37.851376            -122.252523             1996.0
# 989             37.795393            -122.404770             1978.0
# 990             37.785881            -122.408915             1959.0
# 991             37.763316            -122.421904                NaN
# 992             37.868813            -122.258764             1987.0
# 993             37.755213            -122.420975             1962.0
# 994             37.844279            -122.251900             1989.0
# 995             37.781383            -122.389841             1983.0
# 996             37.761420            -122.426435             1970.0
# 997             37.765052            -122.421866             1991.0
# 998             37.752428            -122.420628             1975.0
# 999             37.831277            -122.278267             1943.0
#
#     member_gender       pick_up_address      drop_off_address
# 0          Female        Street Address        Street Address
# 1            Male        Street Address        Street Address
# 2            Male        Street Address        Street Address
# 3          Female        Street Address        Street Address
# 4             NaN        Street Address        Street Address
# 5             NaN        Street Address        Street Address
# 6          Female  Public Place Address        Street Address
# 7            Male        Street Address        Street Address
# 8            Male        Street Address        Street Address
# 9            Male        Street Address        Street Address
# 10           Male        Street Address        Street Address
# 11           Male  Public Place Address  Public Place Address
# 12         Female        Street Address        Street Address
# 13           Male  Public Place Address        Street Address
# 14           Male        Street Address        Street Address
# 15           Male        Street Address        Street Address
# 16         Female  Public Place Address        Street Address
# 17           Male        Street Address        Street Address
# 18           Male        Street Address        Street Address
# 19         Female        Street Address        Street Address
# 20           Male        Street Address        Street Address
# 21           Male        Street Address        Street Address
# 22           Male        Street Address        Street Address
# 23           Male        Street Address        Street Address
# 24            NaN        Street Address        Street Address
# 25          Other        Street Address        Street Address
# 26           Male        Street Address        Street Address
# 27            NaN        Street Address  Public Place Address
# 28          Other        Street Address        Street Address
# 29           Male        Street Address  Public Place Address
# ..            ...                   ...                   ...
# 970           NaN        Street Address        Street Address
# 971          Male        Street Address        Street Address
# 972          Male        Street Address        Street Address
# 973          Male        Street Address        Street Address
# 974          Male        Street Address        Street Address
# 975        Female        Street Address        Street Address
# 976          Male        Street Address        Street Address
# 977        Female        Street Address        Street Address
# 978          Male        Street Address  Public Place Address
# 979        Female        Street Address        Street Address
# 980          Male        Street Address        Street Address
# 981          Male        Street Address        Street Address
# 982          Male        Street Address        Street Address
# 983          Male        Street Address        Street Address
# 984          Male        Street Address        Street Address
# 985          Male        Street Address        Street Address
# 986          Male        Street Address        Street Address
# 987        Female        Street Address        Street Address
# 988        Female        Street Address        Street Address
# 989          Male        Street Address        Street Address
# 990          Male        Street Address        Street Address
# 991           NaN        Street Address        Street Address
# 992          Male        Street Address        Street Address
# 993          Male        Street Address        Street Address
# 994        Female        Street Address        Street Address
# 995          Male        Street Address        Street Address
# 996          Male        Street Address  Public Place Address
# 997        Female        Street Address        Street Address
# 998        Female  Public Place Address        Street Address
# 999          Male        Street Address        Street Address
#
# [1000 rows x 15 columns]

# %%
len(df[df.apply(get_ratio, axis=1) > 65])/len(df)
# Out:
# 1

# %% [markdown]
# Eleventh: exporting dataset to csv.

# %%
df.to_csv(r'SFBiketrips.cvs', index = False)
